# %% [markdown]
# # USING DATA SCIENCE TO FIND THE IDEAL NEW JERSEY SHORE TOWN FOR A NEW SUSTAINABLE MICROBREWERY BUSINESS

# %% [markdown]
# # Part 1: Using the Foursquare API to Explore Asbury Park, Atlantic City, and Cape May, New Jersey

# %% [markdown]
# # ASBURY PARK, NJ

# %% [markdown]
# ### 1. Preliminary Setup

# %% [markdown]
# #### 1.a. Import the libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.0.2s-h7b6447c_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         560 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# #### 1.b. Define Foursquare credentials and version

# %%
CLIENT_ID = 'ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB' # your Foursquare ID
CLIENT_SECRET = 'TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB
# CLIENT_SECRET:TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL

# %% [markdown]
# #### 1.c. Convert the Asbury Park Convention Hall to latitude and longitude coordinates

# %%
address = '1300 Ocean Ave,Asbury Park,NJ'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.2210594 -74.0001747

# %% [markdown]
# ### 2. First we'll locate nearby breweries

# %% [markdown]
# #### 2.a. Search for breweries within 8,000 meters from the Asbury Park Convention Center

# %%
search_query = 'Brewery'
radius = 8000
print(search_query + ' .... OK!')
# Out:
# Brewery .... OK!

# %% [markdown]
# #### 2.b. Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB&client_secret=TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL&ll=40.2210594,-74.0001747&v=20180604&query=Brewery&radius=8000&limit=30'

# %% [markdown]
# #### 2.c. Send the GET request and view the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cffc3074c1f6753b8f6a1c8'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '4e0e22f5a56208c4ea9a85a0',
#       'name': 'Distillery',
#       'pluralName': 'Distilleries',
#       'primary': True,
#       'shortName': 'Distillery'}],
#     'hasPerk': False,
#     'id': '57a50638498e5a58326eddf3',
#     'location': {'address': '810 Sewall Ave',
#      'cc': 'US',
#      'city': 'Asbury Park',
#      'country': 'United States',
#      'distance': 1087,
#      'formattedAddress': ['810 Sewall Ave',
#       'Asbury Park, NJ 07712',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.219424103476,
#        'lng': -74.0127922247425}],
#      'lat': 40.219424103476,
#      'lng': -74.0127922247425,
#      'postalCode': '07712',
#      'state': 'NJ'},
#     'name': 'Asbury Park Brewery',
#     'referralId': 'v-1560265479'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '5b09b014005ac1002c6855f1',
#     'location': {'address': '810 Sewall Ave',
#      'cc': 'US',
#      'city': 'Asbury Park',
#      'country': 'United States',
#      'distance': 1043,
#      'formattedAddress': ['810 Sewall Ave',
#       'Asbury Park, NJ 07712',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.219845,
#        'lng': -74.012352}],
#      'lat': 40.219845,
#      'lng': -74.012352,
#      'postalCode': '07712',
#      'state': 'NJ'},
#     'name': 'Asbury Park Brewery',
#     'referralId': 'v-1560265479'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'primary': True,
#       'shortName': 'Beer Garden'}],
#     'hasPerk': False,
#     'id': '59d8508d002f4c7039ce3502',
#     'location': {'address': '810 Sewall Ave',
#      'cc': 'US',
#      'city': 'Asbury Park',
#      'country': 'United States',
#      'distance': 1083,
#      'formattedAddress': ['810 Sewall Ave',
#       'Asbury Park, NJ 07712',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.219805949564815,
#        'lng': -74.01281654834746}],
#      'lat': 40.219805949564815,
#      'lng': -74.01281654834746,
#      'postalCode': '07712',
#      'state': 'NJ'},
#     'name': 'Asbury Park Brewery',
#     'referralId': 'v-1560265479'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '54f34793498e27464d13aaaa',
#     'location': {'address': '803 Main St',
#      'cc': 'US',
#      'city': 'Belmar',
#      'country': 'United States',
#      'crossStreet': 'Eighth Ave',
#      'distance': 4909,
#      'formattedAddress': ['803 Main St (Eighth Ave)',
#       'Belmar, NJ 07719',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.18126550483192,
#        'lng': -74.02506324265781}],
#      'lat': 40.18126550483192,
#      'lng': -74.02506324265781,
#      'postalCode': '07719',
#      'state': 'NJ'},
#     'name': 'Beach Haus Brewery',
#     'referralId': 'v-1560265479'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '597f3bc1cad1b643aff07675',
#     'location': {'address': '714 Main St',
#      'cc': 'US',
#      'city': 'Bradley Beach',
#      'country': 'United States',
#      'distance': 2338,
#      'formattedAddress': ['714 Main St',
#       'Bradley Beach, NJ 07720',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.20464645042369,
#        'lng': -74.01735162771305}],
#      'lat': 40.20464645042369,
#      'lng': -74.01735162771305,
#      'postalCode': '07720',
#      'state': 'NJ'},
#     'name': 'Bradley Brew Project',
#     'referralId': 'v-1560265479'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '53fc6cf5498e5054f6994261',
#     'location': {'address': '801 Main St',
#      'cc': 'US',
#      'city': 'Belmar',
#      'country': 'United States',
#      'distance': 4808,
#      'formattedAddress': ['801 Main St', 'Belmar, NJ 07719', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.18186800166319,
#        'lng': -74.0239674493438}],
#      'lat': 40.18186800166319,
#      'lng': -74.0239674493438,
#      'postalCode': '07719',
#      'state': 'NJ'},
#     'name': 'East Coast Brewery',
#     'referralId': 'v-1560265479'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '57657658498ec6de8da61eb5',
#     'location': {'cc': 'US',
#      'city': 'Tinton Falls',
#      'country': 'United States',
#      'distance': 6818,
#      'formattedAddress': ['Tinton Falls, NJ', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.235306,
#        'lng': -74.0782}],
#      'lat': 40.235306,
#      'lng': -74.0782,
#      'state': 'NJ'},
#     'name': 'Brown Jug Brewery',
#     'referralId': 'v-1560265479'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '501ed572e4b047a4fadc4099',
#     'location': {'cc': 'US',
#      'city': 'Neptune Township',
#      'country': 'United States',
#      'distance': 7494,
#      'formattedAddress': ['Neptune Township, NJ 07753', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.2078971862793,
#        'lng': -74.08663177490234}],
#      'lat': 40.2078971862793,
#      'lng': -74.08663177490234,
#      'postalCode': '07753',
#      'state': 'NJ'},
#     'name': 'meyer brewery',
#     'referralId': 'v-1560265479'}]}}

# %% [markdown]
# #### 2.d. Get the relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'primary': True, 'id': '4e0e22f5a56208c4ea9a...    False
# 1  [{'primary': True, 'id': '50327c8591d4c4b30a58...    False
# 2  [{'primary': True, 'id': '4bf58dd8d48988d11794...    False
# 3  [{'primary': True, 'id': '50327c8591d4c4b30a58...    False
# 4  [{'primary': True, 'id': '50327c8591d4c4b30a58...    False
#
#                          id location.address location.cc  location.city  \
# 0  57a50638498e5a58326eddf3   810 Sewall Ave          US    Asbury Park
# 1  5b09b014005ac1002c6855f1   810 Sewall Ave          US    Asbury Park
# 2  59d8508d002f4c7039ce3502   810 Sewall Ave          US    Asbury Park
# 3  54f34793498e27464d13aaaa      803 Main St          US         Belmar
# 4  597f3bc1cad1b643aff07675      714 Main St          US  Bradley Beach
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN               1087
# 1    United States                  NaN               1043
# 2    United States                  NaN               1083
# 3    United States           Eighth Ave               4909
# 4    United States                  NaN               2338
#
#                            location.formattedAddress  \
# 0  [810 Sewall Ave, Asbury Park, NJ 07712, United...
# 1  [810 Sewall Ave, Asbury Park, NJ 07712, United...
# 2  [810 Sewall Ave, Asbury Park, NJ 07712, United...
# 3  [803 Main St (Eighth Ave), Belmar, NJ 07719, U...
# 4  [714 Main St, Bradley Beach, NJ 07720, United ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -74.0127922247425...     40.219424
# 1  [{'label': 'display', 'lng': -74.012352, 'lat'...     40.219845
# 2  [{'label': 'display', 'lng': -74.0128165483474...     40.219806
# 3  [{'label': 'display', 'lng': -74.0250632426578...     40.181266
# 4  [{'label': 'display', 'lng': -74.0173516277130...     40.204646
#
#    location.lng location.postalCode location.state                  name  \
# 0    -74.012792               07712             NJ   Asbury Park Brewery
# 1    -74.012352               07712             NJ   Asbury Park Brewery
# 2    -74.012817               07712             NJ   Asbury Park Brewery
# 3    -74.025063               07719             NJ    Beach Haus Brewery
# 4    -74.017352               07720             NJ  Bradley Brew Project
#
#      referralId
# 0  v-1560265479
# 1  v-1560265479
# 2  v-1560265479
# 3  v-1560265479
# 4  v-1560265479

# %% [markdown]
# #### 2.e. Define information of interest and filter the dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                    name   categories         address  cc              city  \
# 0   Asbury Park Brewery   Distillery  810 Sewall Ave  US       Asbury Park
# 1   Asbury Park Brewery      Brewery  810 Sewall Ave  US       Asbury Park
# 2   Asbury Park Brewery  Beer Garden  810 Sewall Ave  US       Asbury Park
# 3    Beach Haus Brewery      Brewery     803 Main St  US            Belmar
# 4  Bradley Brew Project      Brewery     714 Main St  US     Bradley Beach
# 5    East Coast Brewery      Brewery     801 Main St  US            Belmar
# 6     Brown Jug Brewery      Brewery             NaN  US      Tinton Falls
# 7         meyer brewery      Brewery             NaN  US  Neptune Township
#
#          country crossStreet  distance  \
# 0  United States         NaN      1087
# 1  United States         NaN      1043
# 2  United States         NaN      1083
# 3  United States  Eighth Ave      4909
# 4  United States         NaN      2338
# 5  United States         NaN      4808
# 6  United States         NaN      6818
# 7  United States         NaN      7494
#
#                                     formattedAddress  \
# 0  [810 Sewall Ave, Asbury Park, NJ 07712, United...
# 1  [810 Sewall Ave, Asbury Park, NJ 07712, United...
# 2  [810 Sewall Ave, Asbury Park, NJ 07712, United...
# 3  [803 Main St (Eighth Ave), Belmar, NJ 07719, U...
# 4  [714 Main St, Bradley Beach, NJ 07720, United ...
# 5     [801 Main St, Belmar, NJ 07719, United States]
# 6                  [Tinton Falls, NJ, United States]
# 7        [Neptune Township, NJ 07753, United States]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -74.0127922247425...  40.219424 -74.012792
# 1  [{'label': 'display', 'lng': -74.012352, 'lat'...  40.219845 -74.012352
# 2  [{'label': 'display', 'lng': -74.0128165483474...  40.219806 -74.012817
# 3  [{'label': 'display', 'lng': -74.0250632426578...  40.181266 -74.025063
# 4  [{'label': 'display', 'lng': -74.0173516277130...  40.204646 -74.017352
# 5  [{'label': 'display', 'lng': -74.0239674493438...  40.181868 -74.023967
# 6  [{'label': 'display', 'lng': -74.0782, 'lat': ...  40.235306 -74.078200
# 7  [{'label': 'display', 'lng': -74.0866317749023...  40.207897 -74.086632
#
#   postalCode state                        id
# 0      07712    NJ  57a50638498e5a58326eddf3
# 1      07712    NJ  5b09b014005ac1002c6855f1
# 2      07712    NJ  59d8508d002f4c7039ce3502
# 3      07719    NJ  54f34793498e27464d13aaaa
# 4      07720    NJ  597f3bc1cad1b643aff07675
# 5      07719    NJ  53fc6cf5498e5054f6994261
# 6        NaN    NJ  57657658498ec6de8da61eb5
# 7      07753    NJ  501ed572e4b047a4fadc4099

# %% [markdown]
# #### 2.f. Visualize the nearby breweries

# %%
dataframe_filtered.name
# Out:
# 0     Asbury Park Brewery
# 1     Asbury Park Brewery
# 2     Asbury Park Brewery
# 3      Beach Haus Brewery
# 4    Bradley Brew Project
# 5      East Coast Brewery
# 6       Brown Jug Brewery
# 7           meyer brewery
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Asbury Park Convention Hall

# add a red circle marker to represent the Asbury Park Convention Hall
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Asbury Park Convention Hall',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the bars as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3. Next, we'll explore popular spots around the Asbury Park Convention Hall

# %% [markdown]
# #### 3.a. Get the Asbury Park Convention Hall's latitude and longitude coordinates

# %%
latitude = 40.2210594
longitude = -74.0001747

# %% [markdown]
# #### 3.b. Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB&client_secret=TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL&ll=40.2210594,-74.0001747&v=20180604&radius=8000&limit=30'

# %% [markdown]
# #### 3.c. Send the GET request and view the results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} popular venues around Asbury Park Convention Hall.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 popular venues around Asbury Park Convention Hall.'

# %% [markdown]
# #### 3.d. Get the relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4ba3c46af964a520105d38e3-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d1e2941735',
#     'name': 'Beach',
#     'pluralName': 'Beaches',
#     'primary': True,
#     'shortName': 'Beach'}],
#   'id': '4ba3c46af964a520105d38e3',
#   'location': {'address': '1100 Ocean Ave',
#    'cc': 'US',
#    'city': 'Asbury Park',
#    'country': 'United States',
#    'distance': 35,
#    'formattedAddress': ['1100 Ocean Ave',
#     'Asbury Park, NJ 07712',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.22076696115331,
#      'lng': -74.00033724199605}],
#    'lat': 40.22076696115331,
#    'lng': -74.00033724199605,
#    'postalCode': '07712',
#    'state': 'NJ'},
#   'name': 'Asbury Park Boardwalk',
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '38039287'}}}

# %% [markdown]
#  #### 3.e. Process JSON and convert it into a pandas dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                           name         categories          address  cc  \
# 0        Asbury Park Boardwalk              Beach   1100 Ocean Ave  US
# 1               The Stone Pony          Rock Club    913 Ocean Ave  US
# 2            Silverball Museum             Arcade   1000 Ocean Ave  US
# 3               Porta Pizzeria        Pizza Place  911 Kingsley St  US
# 4            Asbury Park Beach              Beach     Ocean Avenue  US
# 5             The Asbury Hotel              Hotel   210 5th Avenue  US
# 6        Ocean Grove Boardwalk              Beach              NaN  US
# 7                   Café Volan        Coffee Shop    510 Bangs Ave  US
# 8  Asbury Park Convention Hall       Concert Hall   1300 Ocean Ave  US
# 9     MOGO Korean Fusion Tacos  Korean Restaurant    850 Ocean Ave  US
#
#           city        country              crossStreet  distance  \
# 0  Asbury Park  United States                      NaN        35
# 1  Asbury Park  United States            at Second Ave       129
# 2  Asbury Park  United States                 3rd Ave.        47
# 3  Asbury Park  United States                      NaN       204
# 4  Asbury Park  United States               8th Avenue       200
# 5  Asbury Park  United States                      NaN       334
# 6  Ocean Grove  United States                      NaN       855
# 7  Asbury Park  United States                      NaN       942
# 8  Asbury Park  United States  btw Asbury & Sunset Ave       322
# 9  Asbury Park  United States   at Boardwalk & 1st Ave       236
#
#                                     formattedAddress  \
# 0  [1100 Ocean Ave, Asbury Park, NJ 07712, United...
# 1  [913 Ocean Ave (at Second Ave), Asbury Park, N...
# 2  [1000 Ocean Ave (3rd Ave.), Asbury Park, NJ 07...
# 3  [911 Kingsley St, Asbury Park, NJ 07712, Unite...
# 4  [Ocean Avenue (8th Avenue), Asbury Park, NJ 07...
# 5  [210 5th Avenue, Asbury Park, NJ 07712, United...
# 6                   [Ocean Grove, NJ, United States]
# 7  [510 Bangs Ave, Asbury Park, NJ 07712, United ...
# 8  [1300 Ocean Ave (btw Asbury & Sunset Ave), Asb...
# 9  [850 Ocean Ave (at Boardwalk & 1st Ave), Asbur...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -74.0003372419960...  40.220767 -74.000337
# 1  [{'label': 'display', 'lng': -74.0008264482090...  40.220011 -74.000826
# 2  [{'label': 'display', 'lng': -73.999717672111,...  40.220819 -73.999718
# 3  [{'label': 'display', 'lng': -74.0022850810057...  40.220179 -74.002285
# 4  [{'label': 'display', 'lng': -73.9988566704195...  40.222554 -73.998857
# 5  [{'label': 'display', 'lng': -74.0019476977748...  40.223744 -74.001948
# 6  [{'label': 'display', 'lng': -74.0034647683540...  40.213796 -74.003465
# 7  [{'label': 'display', 'lng': -74.0096183890049...  40.216631 -74.009618
# 8  [{'label': 'display', 'lng': -73.9986080292506...  40.223702 -73.998608
# 9  [{'label': 'display', 'lng': -74.0004439005559...  40.218949 -74.000444
#
#   postalCode state                        id
# 0      07712    NJ  4ba3c46af964a520105d38e3
# 1      07712    NJ  4aab0148f964a5207f5820e3
# 2      07712    NJ  4b93fb0af964a520bc5e34e3
# 3      07712    NJ  4dea6b8db0fb8293f7d412d3
# 4      07712    NJ  4b7879ccf964a520e8d02ee3
# 5      07712    NJ  57231049498e76d9c825468d
# 6        NaN    NJ  4dffc962d22d5ec6f27661cc
# 7      07712    NJ  4df3e03c45dd4e26934252a1
# 8      07712    NJ  4a90ad92f964a5201d1920e3
# 9      07712    NJ  4f85daf84fc6814193f4ec8a

# %% [markdown]
# #### 3.f. Visualize the popular spots on a map around Asbury Park Convention Hall

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Asbury Park Convention Hall


# add Asbury Park Convention Hall as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Asbury Park Convention Hall',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 4. Now, we'll explore trending venues around the Asbury Park Convention Hall at 9pm on a Saturday

# %% [markdown]
# #### 4.a. Define the corresponding URL

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# %% [markdown]
# #### 4.b. Send the GET request and view the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cffc32fdb04f52f6632b1d8'},
#  'response': {'venues': []}}

# %% [markdown]
# #### 4.c. Visulaize the trending venues

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Asbury Park Convention Hall


    # add Asbury Park Convention Hall as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Asbury Park Convention Hall',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# ## Now let's continue down the coast to Atlantic City...

# %% [markdown]
# # ATLANTIC CITY, NJ

# %% [markdown]
# ### 1. Preliminary Setup

# %% [markdown]
# #### 1.a. The libraries have already been imported

# %% [markdown]
# #### 1.b. The Foursquare credentials and version have already been defined

# %% [markdown]
# #### 1.c. Convert the Atlantic City Convention & Visitor's Authority to latitude and longitude coordinates

# %%
address = '2314 Pacific Ave, Atlantic City, NJ'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.3558257142857 -74.438575

# %% [markdown]
# ### 2. First we'll locate nearby breweries

# %% [markdown]
# #### 2.a. Search for bars within 8,000 meters from the Atlantic City Convention & Visitor's Authority

# %%
search_query = 'Brewery'
radius = 8000
print(search_query + ' .... OK!')
# Out:
# Brewery .... OK!

# %% [markdown]
# #### 2.b. Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB&client_secret=TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL&ll=39.3558257142857,-74.438575&v=20180604&query=Brewery&radius=8000&limit=30'

# %% [markdown]
# #### 2.c. Send the GET request and view the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cffc342351e3d1288ce0082'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '4b074e25f964a520acfb22e3',
#     'location': {'address': '2 Convention Blvd',
#      'cc': 'US',
#      'city': 'Atlantic City',
#      'country': 'United States',
#      'distance': 715,
#      'formattedAddress': ['2 Convention Blvd',
#       'Atlantic City, NJ 08401',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.36223909950674,
#        'lng': -74.43797830512351}],
#      'lat': 39.36223909950674,
#      'lng': -74.43797830512351,
#      'postalCode': '08401',
#      'state': 'NJ'},
#     'name': 'Tun Tavern Restaurant & Brewery',
#     'referralId': 'v-1560265538',
#     'venuePage': {'id': '39963911'}}]}}

# %% [markdown]
# #### 2.d. Get the relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'primary': True, 'id': '50327c8591d4c4b30a58...    False
#
#                          id   location.address location.cc  location.city  \
# 0  4b074e25f964a520acfb22e3  2 Convention Blvd          US  Atlantic City
#
#   location.country  location.distance  \
# 0    United States                715
#
#                            location.formattedAddress  \
# 0  [2 Convention Blvd, Atlantic City, NJ 08401, U...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -74.4379783051235...     39.362239
#
#    location.lng location.postalCode location.state  \
# 0    -74.437978               08401             NJ
#
#                               name    referralId venuePage.id
# 0  Tun Tavern Restaurant & Brewery  v-1560265538     39963911

# %% [markdown]
# #### 2.e. Define information of interest and filter the dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                               name categories            address  cc  \
# 0  Tun Tavern Restaurant & Brewery    Brewery  2 Convention Blvd  US
#
#             city        country  distance  \
# 0  Atlantic City  United States       715
#
#                                     formattedAddress  \
# 0  [2 Convention Blvd, Atlantic City, NJ 08401, U...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -74.4379783051235...  39.362239 -74.437978
#
#   postalCode state                        id
# 0      08401    NJ  4b074e25f964a520acfb22e3

# %% [markdown]
# #### 2.f. Visualize the nearby breweries

# %%
dataframe_filtered.name
# Out:
# 0    Tun Tavern Restaurant & Brewery
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Atlantic City Convention & Visitors Authority

# add a red circle marker to represent the Atlantic City Convention & Visitor's Authority
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Atlantic City Convention & Visitors Authority',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the bars as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3. Next, we'll explore popular spots around the Atlantic City Convention Hall & Visitor's Authority

# %% [markdown]
# #### 3.a. Get the Atlantic City Convention & Visitor's Authority latitude and longitude coordinates

# %%
latitude = 39.3558257142857
longitude = -74.438575

# %% [markdown]
# #### 3.b. Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB&client_secret=TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL&ll=39.3558257142857,-74.438575&v=20180604&radius=8000&limit=30'

# %% [markdown]
# #### 3.c. Send the GET request and view the results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} popular venues around Atlantic City Convention & Visitors Authority.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 popular venues around Atlantic City Convention & Visitors Authority.'

# %% [markdown]
# #### 3.d. Get the relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4b3e97f1f964a520759f25e3-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d110941735',
#     'name': 'Italian Restaurant',
#     'pluralName': 'Italian Restaurants',
#     'primary': True,
#     'shortName': 'Italian'}],
#   'id': '4b3e97f1f964a520759f25e3',
#   'location': {'address': '111 S Albion Pl',
#    'cc': 'US',
#    'city': 'Atlantic City',
#    'country': 'United States',
#    'distance': 421,
#    'formattedAddress': ['111 S Albion Pl',
#     'Atlantic City, NJ 08401',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 39.353486904973394,
#      'lng': -74.44242683073539}],
#    'lat': 39.353486904973394,
#    'lng': -74.44242683073539,
#    'postalCode': '08401',
#    'state': 'NJ'},
#   'name': "Chef Vola's",
#   'photos': {'count': 0, 'groups': []}}}

# %% [markdown]
#  #### 3.e. Process JSON and convert it into a pandas dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                            name           categories  \
# 0                                   Chef Vola's   Italian Restaurant
# 1                              White House Subs       Sandwich Place
# 2                                      Buddakan     Asian Restaurant
# 3                           Dock's Oyster House   Seafood Restaurant
# 4  Ruth's Chris Steak House - Atlantic City, NJ           Steakhouse
# 5                     Angelo's Fairmount Tavern   Italian Restaurant
# 6                                  Wet Willie's                  Bar
# 7                                 Bass Pro Shop  Sporting Goods Shop
# 8                   Gordon Ramsay Pub and Grill           Restaurant
# 9                                      Kelsey's               Lounge
#
#                           address  cc           city        country  \
# 0                 111 S Albion Pl  US  Atlantic City  United States
# 1                 2301 Arctic Ave  US  Atlantic City  United States
# 2                1 Atlantic Ocean  US  Atlantic City  United States
# 3               2405 Atlantic Ave  US  Atlantic City  United States
# 4               2020 Atlantic Ave  US  Atlantic City  United States
# 5              2300 Fairmount Ave  US  Atlantic City  United States
# 6        The Quarter at Tropicana  US  Atlantic City  United States
# 7  30 N Christopher Columbus Blvd  US  Atlantic City  United States
# 8                2100 Pacific Ave  US  Atlantic City  United States
# 9                1545 Pacific Ave  US  Atlantic City  United States
#
#             crossStreet  distance  \
# 0                   NaN       421
# 1  at N Mississippi Ave       416
# 2   The Pier at Caesars       412
# 3                   NaN       231
# 4                   NaN       348
# 5    at Mississippi Ave       521
# 6                   NaN       644
# 7       Atlantic Avenue       311
# 8                   NaN       232
# 9                   NaN       889
#
#                                     formattedAddress  \
# 0  [111 S Albion Pl, Atlantic City, NJ 08401, Uni...
# 1  [2301 Arctic Ave (at N Mississippi Ave), Atlan...
# 2  [1 Atlantic Ocean (The Pier at Caesars), Atlan...
# 3  [2405 Atlantic Ave, Atlantic City, NJ 08401, U...
# 4  [2020 Atlantic Ave, Atlantic City, NJ 08401, U...
# 5  [2300 Fairmount Ave (at Mississippi Ave), Atla...
# 6  [The Quarter at Tropicana, Atlantic City, NJ 0...
# 7  [30 N Christopher Columbus Blvd (Atlantic Aven...
# 8  [2100 Pacific Ave, Atlantic City, NJ 08401, Un...
# 9  [1545 Pacific Ave, Atlantic City, NJ 08401, Un...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -74.4424268307353...  39.353487 -74.442427
# 1  [{'label': 'display', 'lng': -74.4406611, 'lat...  39.359200 -74.440661
# 2  [{'label': 'display', 'lng': -74.4343951, 'lat...  39.354014 -74.434395
# 3  [{'label': 'display', 'lng': -74.440778306585,...  39.357019 -74.440778
# 4  [{'label': 'display', 'lng': -74.4363936781883...  39.358461 -74.436394
# 5  [{'label': 'display', 'lng': -74.441274, 'lat'...  39.360021 -74.441274
# 6  [{'label': 'display', 'lng': -74.4453445434124...  39.353344 -74.445345
# 7  [{'label': 'display', 'lng': -74.4394996762275...  39.358533 -74.439500
# 8  [{'label': 'display', 'lng': -74.4359377178807...  39.356293 -74.435938
# 9  [{'label': 'display', 'lng': -74.4295671789151...  39.359744 -74.429567
#
#   neighborhood postalCode state                        id
# 0          NaN      08401    NJ  4b3e97f1f964a520759f25e3
# 1          NaN      08401    NJ  4a451e8bf964a520cfa71fe3
# 2          NaN      08401    NJ  4b08783bf964a520880c23e3
# 3          NaN      08401    NJ  4b677789f964a520c2502be3
# 4          NaN      08401    NJ  4be8a956ee96c928536afebf
# 5          NaN      08401    NJ  53e28fd3498e2fc1a95f9d40
# 6          NaN      08401    NJ  5205c6dd11d2c03195b2dc65
# 7          NaN      08401    NJ  53c6b052498ea618b36cb6cf
# 8          NaN      08401    NJ  5445023b498e142831e7fc21
# 9          NaN      08401    NJ  51453e78e4b0ec73275ea883

# %% [markdown]
# #### 3.f. Visualize the popular spots on a map around Atlantic City Convention & Visitor's Authority

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Atlantic City Convention & Visitor's Authority


# add Atlantic City Convention & Visitor's Authority as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Atlantic City Convention & Visitors Authority',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 4. Now, we'll explore trending venues around the Atlantic City Convention and Visitor's Authority at 9pm on a Saturday

# %% [markdown]
# #### 4.a. Define the corresponding URL

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# %% [markdown]
# #### 4.b. Send the GET request and view the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cffc3661ed21914bb9be6d6'},
#  'response': {'venues': []}}

# %% [markdown]
# #### 4.c. Visulaize the trending venues

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Asbury Park Convention Hall


    # add Atlantic City Convention & Visitor's Authority as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Atlantic City Convention & Visitors Authority',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Now let's continue further down the coast to Cape May...

# %% [markdown]
# # CAPE MAY, NJ

# %% [markdown]
# ### 1. Preliminary Setup

# %% [markdown]
# #### 1.a. The libraries have already been imported

# %% [markdown]
# #### 1.b. The Foursquare credentials and version have already been defined

# %% [markdown]
# #### 1.c. Convert the Cape May Convention Hall to latitude and longitude coordinates

# %%
address = '714 Beach Ave, Cape May, NJ'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 38.9333597 -74.9055273

# %% [markdown]
# ### 2. First we'll locate nearby breweries

# %% [markdown]
# #### 2.a. Search for bars within 8,000 meters from Cape May Convention Hall

# %%
search_query = 'Brewery'
radius = 8000
print(search_query + ' .... OK!')
# Out:
# Brewery .... OK!

# %% [markdown]
# #### 2.b. Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB&client_secret=TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL&ll=38.9333597,-74.9055273&v=20180604&query=Brewery&radius=8000&limit=30'

# %% [markdown]
# #### 2.c. Send the GET request and view the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cffc37f6a6071493b47c3cc'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '578781c9498e11f1abea043e',
#     'location': {'address': '735 Seashore Rd',
#      'cc': 'US',
#      'city': 'Cape May',
#      'country': 'United States',
#      'distance': 5023,
#      'formattedAddress': ['735 Seashore Rd',
#       'Cape May, NJ 08204',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.97812763973764,
#        'lng': -74.9128095184745}],
#      'lat': 38.97812763973764,
#      'lng': -74.9128095184745,
#      'postalCode': '08204',
#      'state': 'NJ'},
#     'name': 'Cold Spring Brewery',
#     'referralId': 'v-1560265599'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '575b26f3498e3c8b2ca1ed7c',
#     'location': {'address': '3156 Route 9 Soute',
#      'cc': 'US',
#      'city': 'Rio Grande',
#      'country': 'United States',
#      'distance': 10180,
#      'formattedAddress': ['3156 Route 9 Soute',
#       'Rio Grande, NJ 08242',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.02052308206992,
#        'lng': -74.86993602209301}],
#      'lat': 39.02052308206992,
#      'lng': -74.86993602209301,
#      'neighborhood': 'across from walmart',
#      'postalCode': '08242',
#      'state': 'NJ'},
#     'name': '7 Mile Brewery',
#     'referralId': 'v-1560265599',
#     'venuePage': {'id': '200632931'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'primary': True,
#       'shortName': 'Brewery'}],
#     'hasPerk': False,
#     'id': '4e14ba6e091a9211bed4d60a',
#     'location': {'address': '1288 Hornet Rd',
#      'cc': 'US',
#      'city': 'Rio Grande',
#      'country': 'United States',
#      'distance': 7735,
#      'formattedAddress': ['1288 Hornet Rd',
#       'Rio Grande, NJ 08242',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.00262811432539,
#        'lng': -74.91259894894803}],
#      'lat': 39.00262811432539,
#      'lng': -74.91259894894803,
#      'postalCode': '08242',
#      'state': 'NJ'},
#     'name': 'Cape May Brewing Company',
#     'referralId': 'v-1560265599',
#     'venuePage': {'id': '69822487'}}]}}

# %% [markdown]
# #### 2.d. Get the relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'primary': True, 'id': '50327c8591d4c4b30a58...    False
# 1  [{'primary': True, 'id': '50327c8591d4c4b30a58...    False
# 2  [{'primary': True, 'id': '50327c8591d4c4b30a58...    False
#
#                          id    location.address location.cc location.city  \
# 0  578781c9498e11f1abea043e     735 Seashore Rd          US      Cape May
# 1  575b26f3498e3c8b2ca1ed7c  3156 Route 9 Soute          US    Rio Grande
# 2  4e14ba6e091a9211bed4d60a      1288 Hornet Rd          US    Rio Grande
#
#   location.country  location.distance  \
# 0    United States               5023
# 1    United States              10180
# 2    United States               7735
#
#                            location.formattedAddress  \
# 0  [735 Seashore Rd, Cape May, NJ 08204, United S...
# 1  [3156 Route 9 Soute, Rio Grande, NJ 08242, Uni...
# 2  [1288 Hornet Rd, Rio Grande, NJ 08242, United ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lng': -74.9128095184745...     38.978128
# 1  [{'label': 'display', 'lng': -74.8699360220930...     39.020523
# 2  [{'label': 'display', 'lng': -74.9125989489480...     39.002628
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -74.912810                   NaN               08204             NJ
# 1    -74.869936   across from walmart               08242             NJ
# 2    -74.912599                   NaN               08242             NJ
#
#                        name    referralId venuePage.id
# 0       Cold Spring Brewery  v-1560265599          NaN
# 1            7 Mile Brewery  v-1560265599    200632931
# 2  Cape May Brewing Company  v-1560265599     69822487

# %% [markdown]
# #### 2.e. Define information of interest and filter the dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                        name categories             address  cc        city  \
# 0       Cold Spring Brewery    Brewery     735 Seashore Rd  US    Cape May
# 1            7 Mile Brewery    Brewery  3156 Route 9 Soute  US  Rio Grande
# 2  Cape May Brewing Company    Brewery      1288 Hornet Rd  US  Rio Grande
#
#          country  distance                                   formattedAddress  \
# 0  United States      5023  [735 Seashore Rd, Cape May, NJ 08204, United S...
# 1  United States     10180  [3156 Route 9 Soute, Rio Grande, NJ 08242, Uni...
# 2  United States      7735  [1288 Hornet Rd, Rio Grande, NJ 08242, United ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -74.9128095184745...  38.978128 -74.912810
# 1  [{'label': 'display', 'lng': -74.8699360220930...  39.020523 -74.869936
# 2  [{'label': 'display', 'lng': -74.9125989489480...  39.002628 -74.912599
#
#           neighborhood postalCode state                        id
# 0                  NaN      08204    NJ  578781c9498e11f1abea043e
# 1  across from walmart      08242    NJ  575b26f3498e3c8b2ca1ed7c
# 2                  NaN      08242    NJ  4e14ba6e091a9211bed4d60a

# %% [markdown]
# #### 2.f. Visualize the nearby breweries

# %%
dataframe_filtered.name
# Out:
# 0         Cold Spring Brewery
# 1              7 Mile Brewery
# 2    Cape May Brewing Company
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Cape May Convention Hall

# add a red circle marker to represent Cape May Convention Hall
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Cape May Convention Hall',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the bars as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3. Next, we'll explore popular spots around Cape May Convention Hall

# %% [markdown]
# #### 3.a. Get Cape May Convention Hall's latitude and longitude coordinates

# %%
latitude = 38.9333597
longitude = -74.9055273

# %% [markdown]
# #### 3.b. Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=ULWQVLK0GG22R5FVE1433RAPX3ZYELDE4GHWZAA1UKLPB1CB&client_secret=TP54EPGZMLQHFNXDKMFEBCEBCIHFIWORURD4GFFA3LGYMWHL&ll=38.9333597,-74.9055273&v=20180604&radius=8000&limit=30'

# %% [markdown]
# #### 3.c. Send the GET request and view the results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} popular venues around Cape May Convention Hall.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 popular venues around Cape May Convention Hall.'

# %% [markdown]
# #### 3.d. Get the relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4d5ad21d8e105941362fe1e1-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d1c4941735',
#     'name': 'Restaurant',
#     'pluralName': 'Restaurants',
#     'primary': True,
#     'shortName': 'Restaurant'}],
#   'id': '4d5ad21d8e105941362fe1e1',
#   'location': {'address': '1301 Beach Ave',
#    'cc': 'US',
#    'city': 'Cape May',
#    'country': 'United States',
#    'distance': 235,
#    'formattedAddress': ['1301 Beach Ave',
#     'Cape May, NJ 08204',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 38.93453570131723,
#      'lng': -74.90326602607671}],
#    'lat': 38.93453570131723,
#    'lng': -74.90326602607671,
#    'postalCode': '08204',
#    'state': 'NJ'},
#   'name': 'Peter Shields Inn & Restaurant',
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '51122358'}}}

# %% [markdown]
#  #### 3.e. Process JSON and convert it into a pandas dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                              name           categories  \
# 0  Peter Shields Inn & Restaurant           Restaurant
# 1    Cape May Beach and Kite Shop                Beach
# 2  Cape May Peanut Butter Company          Coffee Shop
# 3             Washington St. Mall        Shopping Mall
# 4                      Oyster Bay  American Restaurant
# 5                     Coffee Tyme                 Café
# 6                   Congress Hall                Hotel
# 7                  Washington Inn  American Restaurant
# 8       Brown Room Congress Hotel               Lounge
# 9                 The Ebbitt Room  American Restaurant
#
#                   address  cc      city        country crossStreet  distance  \
# 0          1301 Beach Ave  US  Cape May  United States         NaN       235
# 1             1218 NJ-109  US  Cape May  United States         NaN      1307
# 2        516 Carpenter Ln  US  Cape May  United States       Ocean      1405
# 3       401 Washington St  US  Cape May  United States         NaN      1509
# 4        615 Lafayette St  US  Cape May  United States         NaN      1439
# 5           315 Beach Ave  US  Cape May  United States         NaN      1481
# 6  251 County Highway 604  US  Cape May  United States         NaN      1639
# 7       801 Washington St  US  Cape May  United States         NaN      1195
# 8                Perry St  US  Cape May  United States         NaN      1637
# 9           25 Jackson St  US  Cape May  United States         NaN      1490
#
#                                     formattedAddress  \
# 0  [1301 Beach Ave, Cape May, NJ 08204, United St...
# 1   [1218 NJ-109, Cape May, NJ 08204, United States]
# 2  [516 Carpenter Ln (Ocean), Cape May, NJ 08204,...
# 3  [401 Washington St, Cape May, NJ 08204, United...
# 4  [615 Lafayette St, Cape May, NJ 08204, United ...
# 5  [315 Beach Ave, Cape May, NJ 08204, United Sta...
# 6  [251 County Highway 604, Cape May, NJ 08204, U...
# 7  [801 Washington St, Cape May, NJ 08204, United...
# 8            [Perry St, Cape May, NJ, United States]
# 9  [25 Jackson St, Cape May, NJ 08204, United Sta...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lng': -74.9032660260767...  38.934536 -74.903266
# 1  [{'label': 'display', 'lng': -74.9201950025740...  38.930570 -74.920195
# 2  [{'label': 'display', 'lng': -74.9217267318744...  38.932582 -74.921727
# 3  [{'label': 'display', 'lng': -74.9229466064871...  38.932750 -74.922947
# 4  [{'label': 'display', 'lng': -74.921989745368,...  38.935131 -74.921990
# 5  [{'label': 'display', 'lng': -74.9222213837313...  38.930438 -74.922221
# 6  [{'label': 'display', 'lng': -74.9243102511676...  38.931532 -74.924310
# 7  [{'label': 'display', 'lng': -74.9188073702988...  38.936290 -74.918807
# 8  [{'label': 'display', 'lng': -74.9242832801573...  38.931454 -74.924283
# 9  [{'label': 'display', 'lng': -74.9225688568578...  38.931447 -74.922569
#
#   postalCode state                        id
# 0      08204    NJ  4d5ad21d8e105941362fe1e1
# 1      08204    NJ  4e9c6ac6b803b562d716c89a
# 2      08204    NJ  52beffe111d2699a38abc308
# 3      08204    NJ  4bef164396edc9b690494af2
# 4      08204    NJ  4c194e226a21c9b6fc5bca97
# 5      08204    NJ  4c54159272cf0f4786bdecd3
# 6      08204    NJ  4bc4506edce4eee19516729d
# 7      08204    NJ  5323a5fc498ec90f9d1c01cc
# 8        NaN    NJ  4b1ae41cf964a5200af423e3
# 9      08204    NJ  4c03192539d476b07bb72fa7

# %% [markdown]
# #### 3.f. Visualize the popular spots on a map around Cape May Convention Hall

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Cape May Convention Hall


# add Cape May Convention Hall as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Cape May Convention Hall',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 4. Now, we'll explore trending venues around Cape May Convention Hall at 9pm on a Saturday

# %% [markdown]
# #### 4.a. Define the corresponding URL

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# %% [markdown]
# #### 4.b. Send the GET request and view the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cffc3a1351e3d12873d04d7'},
#  'response': {'venues': []}}

# %% [markdown]
# #### 4.c. Visulaize the trending venues

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Cape May Convention Hall


    # add Cape May Convention Hall as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Cape May Convention Hall',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# # Part 2: Analyzing a Dataset to Determine Population and Environmental Sustainability Efforts of the Counties of Atlantic, Cape May, and Monmouth, and the Towns of Asbury Park, Atlantic City, and Cape May, New Jersey

# %% [markdown]
# ## Preliminary Steps

# %% [markdown]
# ### Import the libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ### Download, read, and view the dataset

# %%
df = pd.read_csv('https://opendata.arcgis.com/datasets/4999349529e64474abcaeefa03f63d0c_18.csv')

df.head()
# Out:
#    OBJECTID              MUN    COUNTY             MUN_LABEL  MUN_TYPE  \
# 0         1    ATLANTIC CITY  ATLANTIC         Atlantic City      City
# 1         2  BRIGANTINE CITY  ATLANTIC       Brigantine City      City
# 2         3  BUENA VISTA TWP  ATLANTIC  Buena Vista Township  Township
# 3         4  EGG HARBOR CITY  ATLANTIC       Egg Harbor City      City
# 4         5     GALLOWAY TWP  ATLANTIC     Galloway Township  Township
#
#                    NAME                GNIS_NAME    GNIS  SSN  MUN_CODE  \
# 0         Atlantic City    City of Atlantic City  885142  102       102
# 1            Brigantine       City of Brigantine  885171  103       103
# 2  Buena Vista Township  Township of Buena Vista  882048  105       105
# 3       Egg Harbor City  City of Egg Harbor City  885204  107       107
# 4     Galloway Township     Township of Galloway  882052  111       111
#
#    CENSUS2010         ACRES    SQ_MILES  POP2010  POP2000  POP1990  POP1980  \
# 0  3400102080  10179.269104   15.905108    39558    40517    37986    40199
# 1  3400107810   6851.199511   10.704999     9450    12594    11354     8318
# 2  3400108710  26607.940658   41.574907     7570     7436     7655     6959
# 3  3400120350   7312.803316   11.426255     4243     4833     4583    19381
# 4  3400125560  71200.879466  111.251374    37349    31209    23330    12176
#
#    POPDEN2010  POPDEN2000  POPDEN1990  POPDEN1980  \
# 0        2488        2547        2388        2527
# 1         883        1176        1061         777
# 2         182         179         184         167
# 3         373         424         402        1702
# 4         336         280         210         109
#
#                                  GLOBALID   SHAPE_Length    SHAPE_Area  \
# 0  {923352D3-6F9A-4C28-A831-A2E430EE6513}   98276.571457  4.434072e+08
# 1  {53709211-2B82-488D-AD4B-6073E0C65922}   91027.546952  2.984371e+08
# 2  {34367BDD-8FEE-4222-9CD7-335002580938}  192780.642861  1.159037e+09
# 3  {276788E5-47CB-4A13-9CC7-9CA33ADD9FDE}  102506.377054  3.185444e+08
# 4  {1E764918-7EC7-4A93-918C-89083AD33627}  354937.882266  3.101498e+09
#
#   CERTIFICATION
# 0        Bronze
# 1        Bronze
# 2        Silver
# 3        Bronze
# 4        Silver

# %% [markdown]
# ## Data Cleanup

# %% [markdown]
# ### Drop the unneeded columns

# %%
df.drop(['OBJECTID','MUN','MUN_LABEL','MUN_TYPE','GNIS_NAME','GNIS','SSN','MUN_CODE','CENSUS2010','ACRES','POP2000','POP1990','POP1980','POPDEN2000','POPDEN1990','POPDEN1980','GLOBALID','SHAPE_Length','SHAPE_Area'], axis = 1, inplace=True)

df.head()
# Out:
#      COUNTY                  NAME    SQ_MILES  POP2010  POPDEN2010  \
# 0  ATLANTIC         Atlantic City   15.905108    39558        2488
# 1  ATLANTIC            Brigantine   10.704999     9450         883
# 2  ATLANTIC  Buena Vista Township   41.574907     7570         182
# 3  ATLANTIC       Egg Harbor City   11.426255     4243         373
# 4  ATLANTIC     Galloway Township  111.251374    37349         336
#
#   CERTIFICATION
# 0        Bronze
# 1        Bronze
# 2        Silver
# 3        Bronze
# 4        Silver

# %% [markdown]
# ### Rename the columns

# %%
df.rename(columns={'NAME':'CITY','SQ_MILES':'SQUARE MILES','POP2010':'POPULATION','POPDEN2010':'POPULATION DENSITY','CERTIFICATION':'SUSTAINABILITY AWARD'}, inplace=True)

df.head()
# Out:
#      COUNTY                  CITY  SQUARE MILES  POPULATION  \
# 0  ATLANTIC         Atlantic City     15.905108       39558
# 1  ATLANTIC            Brigantine     10.704999        9450
# 2  ATLANTIC  Buena Vista Township     41.574907        7570
# 3  ATLANTIC       Egg Harbor City     11.426255        4243
# 4  ATLANTIC     Galloway Township    111.251374       37349
#
#    POPULATION DENSITY SUSTAINABILITY AWARD
# 0                2488               Bronze
# 1                 883               Bronze
# 2                 182               Silver
# 3                 373               Bronze
# 4                 336               Silver

# %% [markdown]
# ### View the dataframe shape and data types

# %%
df.dtypes
# Out:
# COUNTY                   object
# CITY                     object
# SQUARE MILES            float64
# POPULATION                int64
# POPULATION DENSITY        int64
# SUSTAINABILITY AWARD     object
# dtype: object

# %%
df.shape
# Out:
# (200, 6)

# %% [markdown]
# ### Drop the unneeded rows, keeping only Atlantic, Cape May, and Monmouth counties

# %%
df = df.set_index("COUNTY")

df = df.drop(['BERGEN','BURLINGTON','MORRIS','CAMDEN','OCEAN','HUNTERDON','MIDDLESEX','GLOUCESTER','SUSSEX','ESSEX','WARREN','SOMERSET','UNION','PASSAIC','SALEM','CUMBERLAND','HUDSON','MERCER'], axis=0)

df.head()
# Out:
#                           CITY  SQUARE MILES  POPULATION  POPULATION DENSITY  \
# COUNTY
# ATLANTIC         Atlantic City     15.905108       39558                2488
# ATLANTIC            Brigantine     10.704999        9450                 883
# ATLANTIC  Buena Vista Township     41.574907        7570                 182
# ATLANTIC       Egg Harbor City     11.426255        4243                 373
# ATLANTIC     Galloway Township    111.251374       37349                 336
#
#          SUSTAINABILITY AWARD
# COUNTY
# ATLANTIC               Bronze
# ATLANTIC               Bronze
# ATLANTIC               Silver
# ATLANTIC               Bronze
# ATLANTIC               Silver

# %%
df.shape
# Out:
# (41, 5)

# %%
df = df.reset_index()

df.head()
# Out:
#      COUNTY                  CITY  SQUARE MILES  POPULATION  \
# 0  ATLANTIC         Atlantic City     15.905108       39558
# 1  ATLANTIC            Brigantine     10.704999        9450
# 2  ATLANTIC  Buena Vista Township     41.574907        7570
# 3  ATLANTIC       Egg Harbor City     11.426255        4243
# 4  ATLANTIC     Galloway Township    111.251374       37349
#
#    POPULATION DENSITY SUSTAINABILITY AWARD
# 0                2488               Bronze
# 1                 883               Bronze
# 2                 182               Silver
# 3                 373               Bronze
# 4                 336               Silver

# %% [markdown]
# ## Analyze the COUNTY data

# %% [markdown]
# ### View the unique counties

# %%
df['COUNTY'].unique()
# Out:
# array(['ATLANTIC', 'CAPE MAY', 'MONMOUTH'], dtype=object)

# %% [markdown]
# ### Group the data to find out which county has the most square miles

# %%
df_countysq = df[['COUNTY','SQUARE MILES']]

# %%
# grouping results
df_countysq = df_countysq.groupby(['COUNTY'],as_index=False).sum()

# sorting results
df_countysq_sorted = df_countysq.sort_values(by=['SQUARE MILES'], ascending=False)

df_countysq_sorted
# Out:
#      COUNTY  SQUARE MILES
# 0  ATLANTIC    366.472246
# 2  MONMOUTH    218.181419
# 1  CAPE MAY    187.837991

# %% [markdown]
# ### Group the data to find out which county has the biggest population

# %%
df_countypop = df[['COUNTY','POPULATION']]

# %%
# grouping results
df_countypop = df_countypop.groupby(['COUNTY'],as_index=False).sum()

# sorting results
df_countypop_sorted = df_countypop.sort_values(by=['POPULATION'], ascending=False)

df_countypop_sorted
# Out:
#      COUNTY  POPULATION
# 2  MONMOUTH      302028
# 0  ATLANTIC      195499
# 1  CAPE MAY       58734

# %% [markdown]
# ### Group the data to find out which county has the highest poulation density

# %%
df_countypopden = df[['COUNTY','POPULATION DENSITY']]

# %%
# grouping results
df_countypopden = df_countypopden.groupby(['COUNTY'],as_index=False).sum()

# sorting results
df_countypopden_sorted = df_countypopden.sort_values(by=['POPULATION DENSITY'], ascending=False)

df_countypopden_sorted
# Out:
#      COUNTY  POPULATION DENSITY
# 2  MONMOUTH               52771
# 0  ATLANTIC               21051
# 1  CAPE MAY                7843

# %% [markdown]
# ## Analyze the CITY data

# %% [markdown]
# ### View the unique cities

# %%
df['CITY'].unique()
# Out:
# array(['Atlantic City', 'Brigantine', 'Buena Vista Township',
#        'Egg Harbor City', 'Galloway Township', 'Hamilton Township',
#        'Hammonton', 'Linwood', 'Margate City', 'Pleasantville',
#        'Somers Point', 'Ventnor City', 'Avalon Borough', 'Cape May',
#        'Middle Township', 'Ocean City', 'Stone Harbor Borough',
#        'Upper Township', 'Woodbine Borough', 'Atlantic Highlands Borough',
#        'Eatontown Borough', 'Holmdel Township', 'Howell Township',
#        'Keyport Borough', 'Little Silver Borough', 'Marlboro Township',
#        'Middletown Township', 'Ocean Township', 'Red Bank Borough',
#        'Shrewsbury Borough', 'Wall Township', 'Sea Isle City',
#        'Sea Bright Borough', 'West Cape May Borough', 'North Wildwood',
#        'Highlands Borough', 'Roosevelt Borough', 'Cape May Point Borough',
#        'Bradley Beach Borough', 'Longport Borough', 'Asbury Park'], dtype=object)

# %% [markdown]
#  ### Group the data to find out which city has the most square miles

# %%
df_citysq = df[['CITY','SQUARE MILES']]

# %%
# grouping results
df_citysq = df_citysq.groupby(['CITY'],as_index=False).sum()

# sorting results
df_citysq_sorted = df_citysq.sort_values(by=['SQUARE MILES'], ascending=False)

df_citysq_sorted
# Out:
#                           CITY  SQUARE MILES
# 12           Hamilton Township    112.924090
# 11           Galloway Township    111.251374
# 23             Middle Township     82.710932
# 36              Upper Township     68.414485
# 16             Howell Township     61.170255
# 24         Middletown Township     43.538520
# 6         Buena Vista Township     41.574907
# 13                   Hammonton     41.310832
# 38               Wall Township     31.700737
# 22           Marlboro Township     30.433504
# 15            Holmdel Township     18.064123
# 1                Atlantic City     15.905108
# 26                  Ocean City     11.801411
# 10             Egg Harbor City     11.426255
# 27              Ocean Township     10.985099
# 5                   Brigantine     10.704999
# 40            Woodbine Borough      8.018742
# 28               Pleasantville      7.262592
# 9            Eatontown Borough      5.890035
# 34                Somers Point      4.975879
# 3               Avalon Borough      4.967886
# 18                     Linwood      4.360675
# 19       Little Silver Borough      3.180725
# 7                     Cape May      2.882549
# 32               Sea Isle City      2.757348
# 37                Ventnor City      2.549335
# 25              North Wildwood      2.490038
# 35        Stone Harbor Borough      2.312428
# 33          Shrewsbury Borough      2.176598
# 29            Red Bank Borough      2.160315
# 30           Roosevelt Borough      1.947676
# 21                Margate City      1.632162
# 0                  Asbury Park      1.524615
# 17             Keyport Borough      1.449759
# 2   Atlantic Highlands Borough      1.236279
# 31          Sea Bright Borough      1.221324
# 39       West Cape May Borough      1.182092
# 14           Highlands Borough      0.855989
# 4        Bradley Beach Borough      0.645866
# 20            Longport Borough      0.594037
# 8       Cape May Point Borough      0.300080

# %% [markdown]
# ### Group the data to find out which city has the biggest population

# %%
df_citypop = df[['CITY','POPULATION']]

# %%
# grouping results
df_citypop = df_citypop.groupby(['CITY'],as_index=False).sum()

# sorting results
df_citypop_sorted = df_citypop.sort_values(by=['POPULATION'], ascending=False)

df_citypop_sorted
# Out:
#                           CITY  POPULATION
# 24         Middletown Township       66522
# 16             Howell Township       51075
# 22           Marlboro Township       40191
# 1                Atlantic City       39558
# 11           Galloway Township       37349
# 27              Ocean Township       27291
# 12           Hamilton Township       26503
# 38               Wall Township       26164
# 28               Pleasantville       20249
# 23             Middle Township       18911
# 15            Holmdel Township       16773
# 0                  Asbury Park       16116
# 13                   Hammonton       14791
# 9            Eatontown Borough       12709
# 36              Upper Township       12373
# 29            Red Bank Borough       12206
# 26                  Ocean City       11701
# 34                Somers Point       10795
# 37                Ventnor City       10650
# 5                   Brigantine        9450
# 6         Buena Vista Township        7570
# 17             Keyport Borough        7240
# 18                     Linwood        7092
# 21                Margate City        6354
# 19       Little Silver Borough        5950
# 14           Highlands Borough        5005
# 2   Atlantic Highlands Borough        4385
# 4        Bradley Beach Borough        4298
# 10             Egg Harbor City        4243
# 25              North Wildwood        4041
# 33          Shrewsbury Borough        3809
# 7                     Cape May        3607
# 40            Woodbine Borough        2472
# 32               Sea Isle City        2114
# 31          Sea Bright Borough        1412
# 3               Avalon Borough        1334
# 39       West Cape May Borough        1024
# 20            Longport Borough         895
# 30           Roosevelt Borough         882
# 35        Stone Harbor Borough         866
# 8       Cape May Point Borough         291

# %% [markdown]
# ### Group the data to find out which city has the highest poulation density

# %%
df_citypopden = df[['CITY','POPULATION DENSITY']]

# %%
# grouping results
df_citypopden = df_citypopden.groupby(['CITY'],as_index=False).sum()

# sorting results
df_citypopden_sorted = df_citypopden.sort_values(by=['POPULATION DENSITY'], ascending=False)

df_citypopden_sorted
# Out:
#                           CITY  POPULATION DENSITY
# 0                  Asbury Park               10603
# 4        Bradley Beach Borough                6716
# 14           Highlands Borough                5888
# 29            Red Bank Borough                5651
# 17             Keyport Borough                5028
# 37                Ventnor City                4193
# 21                Margate City                3898
# 2   Atlantic Highlands Borough                3565
# 28               Pleasantville                2789
# 1                Atlantic City                2488
# 27              Ocean Township                2486
# 34                Somers Point                2172
# 9            Eatontown Borough                2158
# 19       Little Silver Borough                1871
# 33          Shrewsbury Borough                1755
# 25              North Wildwood                1629
# 18                     Linwood                1627
# 24         Middletown Township                1528
# 20            Longport Borough                1517
# 22           Marlboro Township                1321
# 7                     Cape May                1252
# 31          Sea Bright Borough                1157
# 26                  Ocean City                 992
# 8       Cape May Point Borough                 970
# 15            Holmdel Township                 929
# 5                   Brigantine                 883
# 39       West Cape May Borough                 868
# 16             Howell Township                 835
# 38               Wall Township                 825
# 32               Sea Isle City                 769
# 30           Roosevelt Borough                 455
# 35        Stone Harbor Borough                 375
# 10             Egg Harbor City                 373
# 13                   Hammonton                 358
# 11           Galloway Township                 336
# 40            Woodbine Borough                 309
# 3               Avalon Borough                 269
# 12           Hamilton Township                 235
# 23             Middle Township                 229
# 6         Buena Vista Township                 182
# 36              Upper Township                 181

# %% [markdown]
# ### Group the data by sustainability award level

# %%
dfcitysus = df[['SUSTAINABILITY AWARD','COUNTY','CITY']]

# grouping results
dfcitysus_grouped = dfcitysus.groupby(["SUSTAINABILITY AWARD","COUNTY","CITY"]).count()

dfcitysus_grouped = dfcitysus_grouped.reset_index()

dfcitysus_sorted = dfcitysus_grouped.sort_values(by=['SUSTAINABILITY AWARD','COUNTY','CITY'], ascending=False)

dfcitysus_sorted
# Out:
#    SUSTAINABILITY AWARD    COUNTY                        CITY
# 40               Silver  CAPE MAY        Stone Harbor Borough
# 39               Silver  CAPE MAY                  Ocean City
# 38               Silver  CAPE MAY                    Cape May
# 37               Silver  ATLANTIC                   Hammonton
# 36               Silver  ATLANTIC           Galloway Township
# 35               Silver  ATLANTIC        Buena Vista Township
# 34               Bronze  MONMOUTH               Wall Township
# 33               Bronze  MONMOUTH          Shrewsbury Borough
# 32               Bronze  MONMOUTH          Sea Bright Borough
# 31               Bronze  MONMOUTH           Roosevelt Borough
# 30               Bronze  MONMOUTH            Red Bank Borough
# 29               Bronze  MONMOUTH              Ocean Township
# 28               Bronze  MONMOUTH         Middletown Township
# 27               Bronze  MONMOUTH           Marlboro Township
# 26               Bronze  MONMOUTH       Little Silver Borough
# 25               Bronze  MONMOUTH             Keyport Borough
# 24               Bronze  MONMOUTH             Howell Township
# 23               Bronze  MONMOUTH            Holmdel Township
# 22               Bronze  MONMOUTH           Highlands Borough
# 21               Bronze  MONMOUTH           Eatontown Borough
# 20               Bronze  MONMOUTH       Bradley Beach Borough
# 19               Bronze  MONMOUTH  Atlantic Highlands Borough
# 18               Bronze  MONMOUTH                 Asbury Park
# 17               Bronze  CAPE MAY            Woodbine Borough
# 16               Bronze  CAPE MAY       West Cape May Borough
# 15               Bronze  CAPE MAY              Upper Township
# 14               Bronze  CAPE MAY               Sea Isle City
# 13               Bronze  CAPE MAY              North Wildwood
# 12               Bronze  CAPE MAY             Middle Township
# 11               Bronze  CAPE MAY      Cape May Point Borough
# 10               Bronze  CAPE MAY              Avalon Borough
# 9                Bronze  ATLANTIC                Ventnor City
# 8                Bronze  ATLANTIC                Somers Point
# 7                Bronze  ATLANTIC               Pleasantville
# 6                Bronze  ATLANTIC                Margate City
# 5                Bronze  ATLANTIC            Longport Borough
# 4                Bronze  ATLANTIC                     Linwood
# 3                Bronze  ATLANTIC           Hamilton Township
# 2                Bronze  ATLANTIC             Egg Harbor City
# 1                Bronze  ATLANTIC                  Brigantine
# 0                Bronze  ATLANTIC               Atlantic City
